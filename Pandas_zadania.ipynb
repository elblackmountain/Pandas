# %% [markdown]
# ### Pandas - Zadanie 1 - Dane
#
# ##### Załaduj zbiór danych korzystajac z biblioteki Pandas. Kolumny w naszym zbiorze danych, to:
#
# imię,
# nazwisko,
# rok urodzenia,
# miesiac urodzenia,
# dzień urodzenia,
# miejsce urodzenia,
# miasto, w którym znajduje się oddział firmy,
# departament, w którym pracuje dana osoba,
# rok roczęcia pracy w firmie,
# miesiac rozpoczęcia pracy,
# dzień rozpoczęcia pracy,
# doswiadczenie (w latach)

# %%
import pandas as pd
dataset = pd.read_csv('dataset_pandas_pd.csv')
dataset.columns = 'imię', 'nazwisko', 'rok urodzenia', 'miesiac urodzenia', 'dzień urodzenia','miejsce urodzenia', 'miasto, w którym znajduje się oddział firmy', 'departament, w którym pracuje dana osoba', 'rok roczęcia pracy w firmie','miesiac rozpoczęcia pracy','dzień rozpoczęcia pracy','doswiadczenie (w latach)'
display(dataset.head(5))
# Out:
#         imię nazwisko  rok urodzenia  miesiac urodzenia  dzień urodzenia  \
# 0    Barbara  Babacka           1971                  4                5
# 1     Celina  Cabacka           1969                  6                7
# 2    Dariusz  Dabacki           1972                  8                9
# 3    Ewelina   Ebacka           1968                 10               11
# 4  Ferdynand  Fabacki           1973                 11               12
#
#   miejsce urodzenia miasto, w którym znajduje się oddział firmy  \
# 0            Gdynia                                      Gdansk
# 1             Sopot                                      Gdansk
# 2            Lublin                                      Gdansk
# 3          Warszawa                                      Gdansk
# 4         Walbrzych                                      Gdansk
#
#   departament, w którym pracuje dana osoba  rok roczęcia pracy w firmie  \
# ...

# %% [markdown]
# ### Pandas - Zadanie 2 - Najczęstsze nazwisko
#
# #### Osób o jakim nazwisku jest najwięcej ?

# %%
dataset['nazwisko'].value_counts()[dataset['nazwisko'].value_counts() == dataset['nazwisko'].value_counts().max()]
# Out:
# Babacka    6
# Abacki     6
# Cabacki    6
# Name: nazwisko, dtype: int64

# %%
dataset['nazwisko'].value_counts().idxmax()
# Out:
# 'Babacka'

# %%
#to są moje wczesniejsze próby, chcę je mieć w jednym pliku :-)
dataset.nazwisko.value_counts()
# Out:
# Babacka    6
# Abacki     6
# Cabacki    6
# Dabacki    4
# Ebacka     3
# Fabacki    2
# Abacka     2
# Babacki    2
# Cabacka    1
# Gabacki    1
# Habacka    1
# Ibacka     1
# Gabacka    1
# Dabacka    1
# Ebacki     1
# Fabacka    1
# Name: nazwisko, dtype: int64

# %%
#to są moje wczesniejsze próby, chcę je mieć w jednym pliku :-)
dataset.nazwisko.mode()
# Out:
# 0     Abacki
# 1    Babacka
# 2    Cabacki
# dtype: object

# %% [markdown]
# ### Pandas - Zadanie 3 - Płeć
#
# #### Po kolumnie z nazwiskiem dodaj kolumnę reprezentującą płeć danej osoby. Można wykorzystać fakt, że imiona kobiet kończą się literka 'a'.

# %% [markdown]
# ##### Rozwiązanie 1

# %%
def plec1(x):  # w argumencie zawsze zewnętrzna funkcji, moze być tez lambda
    if x[-1]=='a':
        return 'K'
    else:
        return 'M'

# %%
dataset['płeć'] = dataset['imię'].apply(plec1) # w apply w argumencie zawsze zewnętrzna funkcji, moze być tez lambda

# %%
#potem trzeba zmienić kolejnośc kolumn
dataset = dataset[['imię', 'nazwisko','płeć', 'rok urodzenia', 'miesiac urodzenia', 'dzień urodzenia','miejsce urodzenia', 'miasto, w którym znajduje się oddział firmy', 'departament, w którym pracuje dana osoba', 'rok roczęcia pracy w firmie','miesiac rozpoczęcia pracy','dzień rozpoczęcia pracy','doswiadczenie (w latach)']]

# %%
dataset.head(3)
# Out:
#       imię nazwisko  rok urodzenia  miesiac urodzenia  dzień urodzenia  \
# 0  Barbara  Babacka           1971                  4                5
# 1   Celina  Cabacka           1969                  6                7
# 2  Dariusz  Dabacki           1972                  8                9
#
#   miejsce urodzenia miasto, w którym znajduje się oddział firmy  \
# 0            Gdynia                                      Gdansk
# 1             Sopot                                      Gdansk
# 2            Lublin                                      Gdansk
#
#   departament, w którym pracuje dana osoba  rok roczęcia pracy w firmie  \
# 0                             Data Science                          NaN
# 1                     Software Development                       2013.0
# 2                                       HR                       2020.0
#
#    miesiac rozpoczęcia pracy  dzień rozpoczęcia pracy  \
# 0                          5                       15
# ...

# %% [markdown]
# ##### Rozwiązanie 2

# %%
dataset.drop('płeć', axis=1, inplace = True)

# %%
def plec2(kolumna):
    lista_plci = []
    for i in range(len(kolumna)):
        if kolumna[i][-1] == 'a':
            lista_plci.append('K')
        else:
            lista_plci.append('M')
    
    return lista_plci

# %%
dataset.insert(2, 'płeć', plec2(dataset.imię))

# %%
dataset.head(3)
# Out:
#       imię nazwisko płeć  rok urodzenia  miesiac urodzenia  dzień urodzenia  \
# 0  Barbara  Babacka    K           1971                  4                5
# 1   Celina  Cabacka    K           1969                  6                7
# 2  Dariusz  Dabacki    M           1972                  8                9
#
#   miejsce urodzenia miasto, w którym znajduje się oddział firmy  \
# 0            Gdynia                                      Gdansk
# 1             Sopot                                      Gdansk
# 2            Lublin                                      Gdansk
#
#   departament, w którym pracuje dana osoba  rok roczęcia pracy w firmie  \
# 0                             Data Science                          NaN
# 1                     Software Development                       2013.0
# 2                                       HR                       2020.0
#
#    miesiac rozpoczęcia pracy  dzień rozpoczęcia pracy  \
# ...

# %% [markdown]
# ##### Rozwiązanie 3

# %%
plec3 =  dataset['imię'].apply(lambda imię: imię[-1])=='a'
dataset.insert(2, 'płeć', plec3)
dataset['płeć'] = dataset['płeć'].replace(True, "K")
dataset['płeć'] = dataset['płeć'].replace(False, "M")

# %%
dataset.head(3)
# Out:
#       imię nazwisko płeć  rok urodzenia  miesiac urodzenia  dzień urodzenia  \
# 0  Barbara  Babacka    K           1971                  4                5
# 1   Celina  Cabacka    K           1969                  6                7
# 2  Dariusz  Dabacki    M           1972                  8                9
#
#   miejsce urodzenia miasto, w którym znajduje się oddział firmy  \
# 0            Gdynia                                      Gdansk
# 1             Sopot                                      Gdansk
# 2            Lublin                                      Gdansk
#
#   departament, w którym pracuje dana osoba  rok rozpoczęcia pracy w firmie  \
# 0                             Data Science                             NaN
# 1                     Software Development                          2013.0
# 2                                       HR                          2020.0
#
#    miesiac rozpoczęcia pracy  dzień rozpoczęcia pracy  \
# ...

# %% [markdown]
# ### Zadanie 4 - Sortowanie
#
# #### Posortuj zbiór danych alfabetycznie po nazwiskach, a w ramach jednego nazwiska po roku urodzenia.

# %%
dataset.sort_values(by=['nazwisko', 'rok urodzenia']).head(3)
# Out:
#          imię nazwisko płeć  rok urodzenia  miesiac urodzenia  \
# 21  Anastazja   Abacka    K           1990                  6
# 37     Alicja   Abacka    K           1992                  2
# 15      Roman   Abacki    M           1962                  2
#
#     dzień urodzenia miejsce urodzenia  \
# 21               21            Gdansk
# 37                5            Gdansk
# 15               23            Lublin
#
#    miasto, w którym znajduje się oddział firmy  \
# 21                                      Krakow
# 37                                    Warszawa
# 15                                      Krakow
#
#    departament, w którym pracuje dana osoba  rok roczęcia pracy w firmie  \
# 21                                       HR                       2017.0
# 37                               Accounting                          NaN
# 15                             Data Science                          NaN
#
#     miesiac rozpoczęcia pracy  dzień rozpoczęcia pracy  \
# ...

# %% [markdown]
# ###  Zadanie 5 - Doświadczenie
#
# ##### Do zbioru danych należy dodać kolumnę, która będzie mówiła o poziomie doświadczenia danej osoby, w sposób słowny, przyjmując:
# * Junior (do 3 lat doświadczenia)
# * Mid (4 do 8 lat)
# * Senior (9 do 12 lat)
# * Ekspert (od 13 lat)

# %%
def define_experience(kolumna):
    list_of_exp = []
    for x in range(len(kolumna)):
        if kolumna[x] <=3:
            list_of_exp.append("Junior")
        elif 4<= kolumna[x] <=8:
            list_of_exp.append("Mid")
        elif 9 <= kolumna[x] <= 12:
            list_of_exp.append("Senior")
        else:
            list_of_exp.append("Ekspert")
    return list_of_exp

# %%
dataset.insert(13,'poziom', define_experience(dataset['doswiadczenie (w latach)']))

# %%
dataset.drop('poziom', axis=1, inplace = True)

# %% [markdown]
# #### Gdy nie zależy mi na konkretnym umiejscowieniu kolumny :

# %%
def define_experience2(x):
    if x <=3:
        return "Junior"
    elif 4<= x <=8:
        return "Mid"
    elif 9 <= x <= 12:
        return "Senior"
    else:
        return "Ekspert"

# %%
dataset['poziom'] = dataset['doswiadczenie (w latach)'].apply(define_experience2)

# %% [markdown]
# ### Zadanie 6 - Rok dołączenia
#
# ##### Kolumna reprezentująca rok dołączenia do firmy ma puste wartości. Uzupełnij brakujące wartości używając średniej dla osób o takim samym poziomie doświadczenia (kolumna z Zadania 3), w skali całej firmy.

# %%
dataset = dataset.rename(columns={'rok roczęcia pracy w firmie':'rok rozpoczęcia pracy w firmie'})

# %%
ekspert_mean = round(dataset[dataset.poziom == 'Ekspert']['rok rozpoczęcia pracy w firmie'].mean())
senior_mean = round(dataset[dataset.poziom == 'Senior']['rok rozpoczęcia pracy w firmie'].mean())
mid_mean = round(dataset[dataset.poziom == 'Mid']['rok rozpoczęcia pracy w firmie'].mean())

# %%
dataset[dataset.poziom == 'Junior'] # nie ma żadnych pozycji junior - nie daje się policzyć sredniej, dlatego powyżej tylko 3 zmienne
# Out:
# Empty DataFrame
# Columns: [imię, nazwisko, płeć, rok urodzenia, miesiac urodzenia, dzień urodzenia, miejsce urodzenia, miasto, w którym znajduje się oddział firmy, departament, w którym pracuje dana osoba, rok rozpoczęcia pracy w firmie, miesiac rozpoczęcia pracy, dzień rozpoczęcia pracy, doswiadczenie (w latach), poziom]
# Index: []

# %%
missing_mask = dataset['rok rozpoczęcia pracy w firmie'].isna()
mapping_dict = dict({'Ekspert': ekspert_mean, 'Senior': senior_mean, 'Mid': mid_mean})
dataset.loc[missing_mask, 'rok rozpoczęcia pracy w firmie'] = dataset.loc[missing_mask,'poziom'].map(mapping_dict)

# %%
dataset
# Out:
#           imię nazwisko płeć  rok urodzenia  miesiac urodzenia  \
# 0      Barbara  Babacka    K           1971                  4
# 1       Celina  Cabacka    K           1969                  6
# 2      Dariusz  Dabacki    M           1972                  8
# 3      Ewelina   Ebacka    K           1968                 10
# 4    Ferdynand  Fabacki    M           1973                 11
# 5     Grzegorz  Gabacki    M           1967                 12
# 6       Halina  Habacka    K           1974                 11
# 7        Iwona   Ibacka    K           1966                 10
# 8       Janusz   Abacki    M           1975                  9
# 9     Karolina  Babacka    K           1965                  8
# 10        Leon  Cabacki    M           1976                  7
# 11      Michal  Dabacki    M           1964                  6
# 12     Natalia   Ebacka    K           1977                  5
# 13       Oskar  Fabacki    M           1963                  4
# ...
